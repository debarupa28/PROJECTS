# %% [markdown]
# <a href="https://colab.research.google.com/github/debarupa28/PROJECTS/blob/main/Copy_of_Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
columns=['Sepal Length','Sepal Width','Petal Length','Class_labels']
df=pd.read_csv('/content/Iris.csv',names=columns)
df.head()
# Out:
#                   Sepal Length    Sepal Width  Petal Length Class_labels
# Id SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1  5.1                     3.5            1.4           0.2  Iris-setosa
# 2  4.9                       3            1.4           0.2  Iris-setosa
# 3  4.7                     3.2            1.3           0.2  Iris-setosa
# 4  4.6                     3.1            1.5           0.2  Iris-setosa

# %%
# @title Class_labels

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Class_labels').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
